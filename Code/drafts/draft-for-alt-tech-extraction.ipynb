# %%
import pandas as pd
msg_df = pd.read_csv("E:\._PhD\Publications\SocSem_Telegram\Code\msg_df_with_urls.csv")

# %%
# Filter on alt-tech domains

# List of alt-tech platforms from Wikipedia (https://en.wikipedia.org/wiki/Alt-tech#List_of_alt-tech_platforms)
# # Excluding mainstream social media platforms and inactive platforms we couldn't trace a URL for
alt = {"Gab": "gab.com",
"Gettr" : "gettr.com",
"Parler" : "parler.com",
"Truth Social" : "truthsocial.com",
"BitChute" : "bitchute.com",
"DLive" : "dlive.tv",
"DTube" : "d.tube",
"Odysee" : "lbry.com",
"PewTube" : "pewtube.com",
"Rumble" : "rumble.com",
"Triller" : "triller.co",
"GiveSendGo" : "givesendgo.com",
"Hatreon" : "hatreon.net",
"SubscribeStar" : "subscribestar.com",
"GoyFundMe" : "goyfundme.com",
"MeWe" : "mewe.com",
"Minds" : "minds.com",
"Thinkspot" : "thinkspot.com",
"Patriots.win" : "patriots.win",
"Infogalactic" : "infogalactic.com",
"Metapedia" : "metapedia.org",
"8kun" : "8kun.top",
"WASP Love" : "wasplove.com",
"JustPaste.it" : "justpaste.it",
"Epik" : "epik.com"}

# %%
import ast
[url for sublist in msg_df.url for url in ast.literal_eval(sublist)]
# Out:
# ['www.pewtrusts.org',
#  'www.infowars.com',
#  'siegekultur.biz',
#  'twitter.com',
#  'www.pakin.org',
#  'twitter.com',
#  'www.nbcnews.com',
#  'youtu.be',
#  'www.zerohedge.com',
#  'en.wikipedia.org',
#  'en.wikipedia.org',
#  'www.qwant.com',
#  'duckduckgo.com',
#  'startpage.com',
#  'ixquick.com',
#  'searx.me',
#  'www.ecosia.org',
#  'search.yacy.net',
#  'goodgopher.com',
#  '1776free.com',
#  'www.bing.com',
#  'gab.ai',
#  'poal.co',
#  'shitposters.club',
#  'sealion.club',
#  'freezepeach.xyz',
#  'voat.co',
#  'iscute.moe',
#  'social.ufeff.club',
#  'd.tube',
#  'dlive.tv',
#  'bit.tube',
#  'www.brighteon.com',
#  'invidio.us',
#  'pe.ertu.be',
#  'ugetube.com',
#  'hooktube.com',
#  'www.liveleak.com',
#  'www.bitchute.com',
#  'dissenter.com',
#  'www.minds.com',
#  'streambotz.com',
#  'unseen.is',
#  'joinalbin.com',
#  'usa.life',
#  'www.signal.org',
#  'freedom.social',
#  'mastodon.social',
#  'steemit.com',
#  'joindiaspora.com',
#  'www.snabbo.com',
#  'medium.com',
#  'www.spreely.com',
#  'www.youtube.com',
#  'www.forbes.com',
#  'www.youtube.com',
#  'www.youtube.com',
#  'www.instructables.com',
#  'archive.is',
#  'www.qrz.com',
#  'caucus99percent.com',
#  'is2.4chan.org',
#  'www.youtube.com',
#  'twitter.com',
#  'linuxmail.org',
#  't.me',
#  't.co',
#  'twitter.com',
#  'youtu.be',
#  'abcnews.go.com',
#  'www.youtube.com',
#  'youtu.be',
#  'archive.org',
#  't.co',
#  'twitter.com',
#  'www.youtube.com',
#  'telegra.ph',
#  'twitter.com',
#  'youtu.be',
#  'youtu.be',
#  'www.youtube.com',
#  'pastebin.com',
#  't.me',
#  'youtu.be',
#  'boards.4chan.org',
#  'youtu.be',
#  'identitydixie.com',
#  'identitydixie.com',
#  'youtu.be',
#  'www.bitchute.com',
#  'youtu.be',
#  'youtu.be',
#  'www.youtube.com',
#  'www.bitchute.com',
#  'www.bitchute.com',
#  'www.bitchute.com',
#  'www.bitchute.com',
#  'www.bitchute.com',
#  'www.bitchute.com',
#  'www.bitchute.com',
#  'www.bitchute.com',
#  'www.bitchute.com',
#  'www.bitchute.com',
#  'youtu.be',
#  'www.youtube.com',
#  'abcnews.go.com',
#  'youtu.be',
#  'feedproxy.google.com',
#  'youtu.be',
#  'feedproxy.google.com',
#  'youtu.be',
#  'www.zdnet.com',
#  'www.zdnet.com',
#  'thegreateststorynevertold.tv',
#  'www.radioaryan.com',
#  'www.zdnet.com',
#  'www.youtube.com',
#  'www.youtube.com',
#  'www.youtube.com',
#  'mega.nz',
#  't.me',
#  'www.bbc.co.uk',
#  'www.bitchute.com',
#  'www.latimes.com',
#  'en.wikipedia.org',
#  'en.m.wikipedia.org',
#  'breaking911.com',
#  'breaking911.com',
#  'www.zerohedge.com',
#  'youtube.com',
#  'twitter.com',
#  'www.bitchute.com',
#  'caldronpool.com',
#  'youtu.be',
#  'youtu.be',
#  'youtu.be',
#  'theguardian.com',
#  'T.me',
#  'youtu.be',
#  'www.facebook.com',
#  'youtu.be',
#  'feedproxy.google.com',
#  'foreignpolicy.com',
#  'mobile.twitter.com',
#  'screencrush.com',
#  'talkingpointsmemo.com',
#  'feedproxy.google.com',
#  'www.bitchute.com',
#  'www.bitchute.com',
#  'youtu.be',
#  'twitter.com',
#  'www.bitchute.com',
#  'time.com',
#  'www.bbc.co.uk',
#  'usdailyreport.com',
#  'www.bitchute.com',
#  'www.nytimes.com',
#  'thundertactical.com',
#  'jtactical.com',
#  'youtu.be',
#  'youtu.be',
#  'youtu.be',
#  'm.worldstarhiphop.com',
#  'twitter.com',
#  'www.pinknews.co.uk',
#  'medium.com',
#  'archive.is',
#  'www.youtube.com',
#  'www.youtube.com',
#  'mobile.twitter.com',
#  'www.bitchute.com',
#  'nypost.com',
#  'www.youtube.com',
#  't.me',
#  'www.bitchute.com',
#  'www.congress.gov',
#  'youtu.be',
#  'telegram.org',
#  't.me',
#  'youtu.be',
#  'mobile.twitter.com',
#  'youtu.be',
#  'youtu.be',
#  'youtu.be',
#  'twitter.com',
#  'www.infowars.com',
#  'www.youtube.com',
#  'twitter.com',
#  'baltimore.cbslocal.com',
#  'youtu.be',
#  'pastebin.com',
#  'edition.cnn.com',
#  'youtu.be',
#  't.me',
#  'youtu.be',
#  'twitter.com',
#  'twitter.com',
#  'gizmodo.com',
#  'dlive.tv',
#  'dlive.tv',
#  'amp.usatoday.com',
#  'americanmilitarynews.com',
#  't.me',
#  'twitter.com',
#  'youtu.be',
#  'youtu.be',
#  't.me',
#  'youtu.be',
#  'feedproxy.google.com',
#  't.me',
#  'youtu.be',
#  't.me',
#  'pastebin.com',
#  'twitter.com',
#  't.me',
#  'twitter.com',
#  'www.skylighter.com',
#  't.me',
#  'www.youtube.com',
#  '8ch.net',
#  'twitter.com',
#  'www.youtube.com',
#  'www.instagram.com',
#  'www.bitchute.com',
#  'twitter.com',
#  'www.youtube.com',
#  'www.youtube.com',
#  'www.pewtrusts.org',
#  'www.infowars.com',
#  'twitter.com',
#  'twitter.com',
#  'youtu.be',
#  'www.zerohedge.com',
#  'en.wikipedia.org',
#  'www.youtube.com',
#  'archive.is',
#  'www.qrz.com',
#  'archive.org',
#  'identitydixie.com',
#  'abcnews.go.com',
#  'www.youtube.com',
#  'www.latimes.com',
#  'breaking911.com',
#  'theguardian.com',
#  'youtu.be',
#  'mobile.twitter.com',
#  'twitter.com',
#  'time.com',
#  'usdailyreport.com',
#  'www.nytimes.com',
#  'thundertactical.com',
#  'jtactical.com',
#  'youtu.be',
#  'youtu.be',
#  'youtu.be',
#  'm.worldstarhiphop.com',
#  'mobile.twitter.com',
#  't.co',
#  'twitter.com',
#  'nypost.com',
#  't.me',
#  'mobile.twitter.com',
#  'youtu.be',
#  'youtu.be',
#  'youtu.be',
#  'www.infowars.com',
#  'twitter.com',
#  'wamu.org',
#  'baltimore.cbslocal.com',
#  'youtu.be',
#  'edition.cnn.com',
#  'youtu.be',
#  'twitter.com',
#  'gizmodo.com',
#  'twitter.com',
#  'youtu.be',
#  'youtu.be',
#  't.me',
#  't.me',
#  'youtu.be',
#  't.me',
#  'pastebin.com',
#  't.me',
#  'www.skylighter.com',
#  't.me',
#  'www.youtube.com',
#  '8ch.net',
#  'twitter.com',
#  'www.bitchute.com',
#  'www.youtube.com',
#  'www.history.com',
#  'twitter.com',
#  'www.lifesitenews.com',
#  'm.youtube.com',
#  'www.youtube.com',
#  'www.youtube.com',
#  'youtu.be',
#  'twitter.com',
#  'www.thelocal.no',
#  'twitter.com',
#  'm.youtube.com',
#  'twitter.com',
#  'throwflame.com',
#  'twitter.com',
#  'twitter.com',
#  'www.thedailybeast.com',
#  'www.youtube.com',
#  'www.foxnews.com',
#  'twitter.com',
#  'twitter.com',
#  'youtu.be',
#  'mobile.twitter.com',
#  'twitter.com',
#  'www.youtube.com',
#  'feedproxy.google.com',
#  'www.chabad.org',
#  'www.chabad.org',
#  'www.ynetnews.com',
#  't.me',
#  'telegra.ph',
#  'bit.ly',
#  't.me',
#  'twitter.com',
#  'ocweekly.com',
#  'talkingpointsmemo.com',
#  'www.torproject.org',
#  'www.dragqueenstoryhour.org',
#  'www.bbc.com',
#  'www.thelocal.de',
#  'www.natgeomaps.com',
#  'www.cbsnews.com',
#  't.me',
#  't.me',
#  't.me',
#  'm.youtube.com',
#  't.co',
#  'www.2acheck.com',
#  'twitter.com',
#  'www.bitchute.com',
#  'www.bitchute.com',
#  'youtu.be',
#  'www.bitchute.com',
#  'www.bitchute.com',
#  'www.bitchute.com',
#  'techultras.com',
#  'youtu.be',
#  'www.cbc.ca',
#  'www.wweek.com',
#  'www.bitchute.com',
#  'www.nhregister.com',
#  'www.bitchute.com',
#  'www.aljazeera.com',
#  'www.bitchute.com',
#  'www.thegatewaypundit.com',
#  'www.bitchute.com',
#  'www.lifesitenews.com',
#  'www.bitchute.com',
#  'youtu.be',
#  'm.facebook.com',
#  'youtu.be',
#  'www.theunshackled.net',
#  'youtu.be',
#  'nypost.com',
#  'www.bitchute.com',
#  'whyy.org',
#  'mobile.twitter.com',
#  'nationalfile.com',
#  'nationalfile.com',
#  'www.bitchute.com',
#  'twitter.com',
#  'www.bitchute.com',
#  'www.gofundme.com',
#  'nationalfile.com',
#  'proudboysusa.com',
#  'www.bitchute.com',
#  'www.bitchute.com',
#  'www.bitchute.com',
#  'www.bitchute.com',
#  'twitter.com',
#  'nationalfile.com',
#  'www.thegatewaypundit.com',
#  'www.bitchute.com',
#  'twitter.com',
#  'youtu.be',
#  't.me',
#  'www.bitchute.com',
#  'par.pw',
#  'twitter.com',
#  'twitter.com',
#  'twitter.com',
#  'twitter.com',
#  't.me',
#  'www.bitchute.com',
#  'www.bitchute.com',
#  'www.bitchute.com',
#  'www.bitchute.com',
#  'www.bitchute.com',
#  'twitter.com',
#  'twitter.com',
#  'summit.news',
#  'www.bitchute.com',
#  'mobile.twitter.com',
#  'www.thegatewaypundit.com',
#  'youtu.be',
#  'www.newmediacentral.net',
#  'twitter.com',
#  'youtu.be',
#  'www.bitchute.com',
#  'www.tr.news',
#  'twitter.com',
#  'twitter.com',
#  'summit.news',
#  'twitter.com',
#  'twitter.com',
#  'www.huffingtonpost.ca',
#  'www.redwhiteandfyou.com',
#  'www.dangerous.com',
#  'youtu.be',
#  'twitter.com',
#  'twitter.com',
#  'twitter.com',
#  'twitter.com',
#  'www.bitchute.com',
#  'twitter.com',
#  'youtu.be',
#  'lauraloomer.us',
#  'youtu.be',
#  'www.youtube.com',
#  'youtu.be',
#  'www.fox4news.com',
#  'twitter.com',
#  'twitter.com',
#  'lauraloomer.us',
#  'youtu.be',
#  'www.bitchute.com',
#  'twitter.com',
#  'twitter.com',
#  'twitter.com',
#  'www.youtube.com',
#  'youtu.be',
#  'twitter.com',
#  'www.bitchute.com',
#  'youtu.be',
#  'twitter.com',
#  'twitter.com',
#  'twitter.com',
#  'twitter.com',
#  'gasdigitalnetwork.com',
#  'www.bitchute.com',
#  'twitter.com',
#  'www.facebook.com',
#  'youtu.be',
#  'youtu.be',
#  'www.youtube.com',
#  't.me',
#  't.me',
#  't.me',
#  't.me',
#  't.me',
#  't.me',
#  't.me',
#  't.me',
#  't.me',
#  't.me',
#  't.me',
#  't.me',
#  't.me',
#  't.me',
#  't.me',
#  'thefederalistpapers.org',
#  'forward.com',
#  'twitter.com',
#  'townhall.com',
#  'www.bitchute.com',
#  'www.bitchute.com',
#  'www.nbcnews.com',
#  'telegra.ph',
#  'redice.tv',
#  'www.kalkiweisthor.net',
#  'redice.tv',
#  'www.kalkiweisthor.net',
#  'www.spreaker.com',
#  'm.youtube.com',
#  'm.youtube.com',
#  'm.youtube.com',
#  'm.youtube.com',
#  'm.youtube.com',
#  'm.youtube.com',
#  'm.youtube.com',
#  'm.youtube.com',
#  'm.youtube.com',
#  'archive.org',
#  'archive.org',
#  'www.thewardenpost.com',
#  'youtu.be',
#  'news.vice.com',
#  'metro.co.uk',
#  'www.torproject.org',
#  'www.thelocal.de',
#  'imgur.com',
#  'm.startribune.com',
#  'identitydixie.com',
#  'goytalk.com',
#  'www.latimes.com',
#  'www.rt.com',
#  'twitter.com',
#  'www.vice.com',
#  'youtu.be',
#  'youtu.be',
#  'www.timesofisrael.com',
#  'www.rt.com',
#  'www.bbc.com',
#  'www.rt.com',
#  'twitter.com',
#  'www.news.com.au',
#  'www.youtube.com',
#  'youtu.be',
#  '8ch.net',
#  'www.bitchute.com',
#  'www.bitchute.com',
#  't.me',
#  't.me',
#  't.me',
#  't.me',
#  't.me',
#  't.me',
#  't.me',
#  'twitter.com',
#  'youtu.be',
#  'youtu.be',
#  'www.youtube.com',
#  'www.breitbart.com',
#  'ia800301.us.archive.org',
#  'twitter.com',
#  'twitter.com',
#  'twitter.com',
#  'twitter.com',
#  'twitter.com',
#  'twitter.com',
#  't.me',
#  'www.courthousenews.com',
#  'teespring.com',
#  'twitter.com',
#  'twitter.com',
#  'youtu.be',
#  't.me',
#  'www.bitchute.com',
#  'www.bitchute.com',
#  'www.bitchute.com',
#  'www.bitchute.com',
#  'www.bitchute.com',
#  'www.bitchute.com',
#  'www.bitchute.com',
#  'www.bitchute.com',
#  'www.huffingtonpost.ca',
#  'www.infowars.com',
#  'www.dangerous.com',
#  'twitter.com',
#  'www.bitchute.com',
#  'www.bitchute.com',
#  'www.bitchute.com',
#  'twitter.com',
#  'www.bitchute.com',
#  'www.dailymail.co.uk',
#  'youtu.be',
#  'www.bitchute.com',
#  'www.bitchute.com',
#  'www.youtube.com',
#  'www.bitchute.com',
#  'youtu.be',
#  'www.fox4news.com',
#  'www.bitchute.com',
#  'youtu.be',
#  'www.bitchute.com',
#  'www.bitchute.com',
#  'www.bitchute.com',
#  'twitter.com',
#  'youtu.be',
#  'youtu.be',
#  'twitter.com',
#  'youtu.be',
#  'www.thedailybeast.com',
#  'www.bitchute.com',
#  'youtu.be',
#  'twitter.com',
#  'twitter.com',
#  'www.bitchute.com',
#  'www.bitchute.com',
#  'youtu.be',
#  'www.bitchute.com',
#  'www.bitchute.com',
#  'www.bitchute.com',
#  'www.thegatewaypundit.com',
#  'www.bitchute.com',
#  'petitions.whitehouse.gov',
#  'bigleaguepolitics.com',
#  'www.foxnews.com',
#  'petitions.whitehouse.gov',
#  'petitions.whitehouse.gov',
#  'www.bitchute.com',
#  'www.bitchute.com',
#  'www.bitchute.com',
#  'www.bitchute.com',
#  'www.thespec.com',
#  'www.bitchute.com',
#  'www.bitchute.com',
#  'apple.news',
#  'amp.scmp.com',
#  'www.bitchute.com',
#  'www.bitchute.com',
#  'www.bitchute.com',
#  'lauraloomer.us',
#  'twitter.com',
#  'www.bitchute.com',
#  'StopTheSlander.com',
#  'www.bitchute.com',
#  'www.bitchute.com',
#  'www.bitchute.com',
#  'www.bitchute.com',
#  'www.bitchute.com',
#  'www.bitchute.com',
#  'Stlawu.edu',
#  'www.independent.co.uk',
#  'www.washingtonexaminer.com',
#  'twitter.com',
#  'www.bitchute.com',
#  'Stlawu.edu',
#  'www.independent.co.uk',
#  'www.washingtonexaminer.com',
#  'twitter.com',
#  'Stlawu.edu',
#  'www.independent.co.uk',
#  'www.washingtonexaminer.com',
#  'twitter.com',
#  'Stlawu.edu',
#  'www.independent.co.uk',
#  'www.washingtonexaminer.com',
#  'twitter.com',
#  'Stlawu.edu',
#  'www.independent.co.uk',
#  'www.washingtonexaminer.com',
#  'twitter.com',
#  'Stlawu.edu',
#  'www.independent.co.uk',
#  'www.washingtonexaminer.com',
#  'twitter.com',
#  'youtu.be',
#  'www.tr.news',
#  'twitter.com',
#  'youtu.be',
#  'www.tr.news',
#  'bigleaguepolitics.com',
#  'www.nytimes.com',
#  'twitter.com',
#  'twitter.com',
#  'www.politico.eu',
#  'StopTheSlander.com',
#  'pjmedia.com',
#  'summit.news',
#  'www.youtube.com',
#  'www.gofundme.com',
#  'youtu.be',
#  'twitter.com',
#  'twitter.com',
#  'www.facebook.com',
#  'twitter.com',
#  'www.facebook.com',
#  'twitter.com',
#  'twitter.com',
#  'm.facebook.com',
#  'whitehouse.typeform.com',
#  'www.google.com',
#  'www.facebook.com',
#  'www.gofundme.com',
#  't.me',
#  't.me',
#  'teespring.com',
#  'twitter.com',
#  't.co',
#  'youtu.be',
#  'm.youtube.com',
#  'www.youtube.com',
#  't.me',
#  'www.scribd.com',
#  'www.nytimes.com',
#  'www.bitchute.com',
#  'nypost.com',
#  'twitter.com',
#  'twitter.com',
#  'twitter.com',
#  'www.nytimes.com',
#  'twitter.com',
#  'twitter.com',
#  'www.abcactionnews.com',
#  'twitter.com',
#  'youtu.be',
#  'summit.news',
#  'twitter.com',
#  'mobile.twitter.com',
#  'www.youtube.com',
#  'rightoftheright.com',
#  'www.theunshackled.net',
#  'www.dw.com',
#  'youtu.be',
#  'twitter.com',
#  'www.dailystar.co.uk',
#  'www.judicialwatch.org',
#  'www.express.co.uk',
#  'www.thelocal.de',
#  'twitter.com',
#  'youtu.be',
#  'youtu.be',
#  'mobile.twitter.com',
#  't.me',
#  't.me',
#  'www.dailydot.com',
#  'cbsn.ws',
#  'firearmsunknown.com',
#  't.me',
#  't.me',
#  't.me',
#  't.me',
#  't.me',
#  't.me',
#  't.me',
#  't.me',
#  't.me',
#  't.me',
#  't.me',
#  't.me',
#  'twitter.com',
#  'youtu.be',
#  't.me',
#  't.me',
#  't.me',
#  't.me',
#  't.me',
#  'www.dailypress.com',
#  't.me',
#  't.me',
#  't.me',
#  't.me',
#  't.me',
#  'nypost.com',
#  'twitter.com',
#  'www.nationalgeographic.com',
#  'mobile.twitter.com',
#  'www.dw.com',
#  't.me',
#  'twitter.com',
#  'www.eff.org',
#  'www.youtube.com',
#  'summit.news',
#  'youtu.be',
#  'www.dailymail.co.uk',
#  'asiancorrespondent.com',
#  'twitter.com',
#  'timeline.com',
#  'twitter.com',
#  'twitter.com',
#  'www.wired.co.uk',
#  't.co',
#  'thegoldenone.se',
#  'www.foxnews.com',
#  'www.foxnews.com',
#  'www.youtube.com',
#  'youtu.be',
#  'youtu.be',
#  'www.actuall.com',
#  'www.foxnews.com',
#  'www.youtube.com',
#  'www.youtube.com',
#  'kontrainfo.com',
#  'www.youtube.com',
#  'm.perfil.com',
#  'kontrainfo.com',
#  'youtu.be',
#  'www.youtube.com',
#  'www.telecinco.es',
#  'www.youtube.com',
#  'kontrainfo.com',
#  'www.cbsnews.com',
#  'www.youtube.com',
#  'www.youtube.com',
#  'www.eldisenso.com',
#  'youtu.be',
#  'www.abc.es',
#  'www.facebook.com',
#  'youtu.be',
#  'glse.org',
#  'www.alertanacional.es',
#  'youtu.be',
#  'youtu.be',
#  'youtu.be',
#  'youtu.be',
#  'youtu.be',
#  'youtu.be',
#  'youtu.be',
#  'youtu.be',
#  'youtu.be',
#  'youtu.be',
#  'youtu.be',
#  'youtu.be',
#  'youtu.be',
#  'kontrainfo.com',
#  'www.youtube.com',
#  'www.youtube.com',
#  'www.youtube.com',
#  'www.eldisenso.com',
#  'www.lifenews.com',
#  'www.aciprensa.com',
#  'www.eldisenso.com',
#  'LifeNews.com',
#  'www.lifenews.com',
#  'www.eldisenso.com',
#  'twitter.com',
#  'youtu.be',
#  'youtu.be',
#  'youtu.be',
#  'youtu.be',
#  'youtu.be',
#  'youtu.be',
#  'youtu.be',
#  'youtu.be',
#  'bigleaguepolitics.com',
#  'secure.anedot.com',
#  'twitter.com',
#  'youtu.be',
#  'www.dangerous.com',
#  'petitions.whitehouse.gov',
#  't.me',
#  'petitions.whitehouse.gov',
#  'twitter.com',
#  'www.breitbart.com',
#  't.me',
#  'alloutdc.org',
#  'summit.news',
#  'www.infowars.com',
#  'twitter.com',
#  'twitter.com',
#  'www.infowars.com',
#  'order-order.com',
#  'www.jaydafransen.online',
#  'lauraloomer.us',
#  'www.bitchute.com',
#  'par.pw',
#  'www.infowars.com',
#  'montreal.ctvnews.ca',
#  'europe.infowars.com',
#  'bigleaguepolitics.com',
#  't.co',
#  'twitter.com',
#  'summit.news',
#  'youtu.be',
#  'youtu.be',
#  'www.infowars.com',
#  'twitter.com',
#  'europe.infowars.com',
#  'summit.news',
#  'twitter.com',
#  'www.tr.news',
#  'www.infowars.com',
#  'twitter.com',
#  'summit.news',
#  'summit.news',
#  'twitter.com',
#  'summit.news',
#  'youtu.be',
#  'HongKongReports.com',
#  'summit.news',
#  'summit.news',
#  'lauraloomer.us',
#  'www.bitchute.com',
#  'summit.news',
#  'summit.news',
#  'www.spencerfernando.com',
#  'twitter.com',
#  'youtu.be',
#  'youtu.be',
#  'www.youtube.com',
#  'bigleaguepolitics.com',
#  'twitter.com',
#  'twitter.com',
#  'twitter.com',
#  'www.infowars.com',
#  'www.infowars.com',
#  'twitter.com',
#  'twitter.com',
#  'summit.news',
#  'www.instagram.com',
#  'twitter.com',
#  'twitter.com',
#  'twitter.com',
#  'twitter.com',
#  'secure.anedot.com',
#  'europe.infowars.com',
#  'politichatter.com',
#  'twitter.com',
#  'summit.news',
#  'www.infowars.com',
#  'www.fox5ny.com',
#  'summit.news',
#  'metro.co.uk',
#  'twitter.com',
#  'metro.co.uk',
#  'www.tr.news',
#  'twitter.com',
#  'twitter.com',
#  'twitter.com',
#  'www.youtube.com',
#  'www.infowars.com',
#  'nationalpost.com',
#  'summit.news',
#  'www.youtube.com',
#  'www.infowars.com',
#  'lauraloomer.us',
#  'www.tr.news',
#  'www.tr.news',
#  'twitter.com',
#  'summit.news',
#  'summit.news',
#  'summit.news',
#  'twitter.com',
#  'lauraloomer.us',
#  'politichatter.com',
#  'summit.news',
#  'summit.news',
#  'www.infowars.com',
#  'youtu.be',
#  'www.SaveSheila.com',
#  'youtu.be',
#  'www.infowars.com',
#  'twitter.com',
#  'twitter.com',
#  'www.cbsnews.com',
#  'twitter.com',
#  'twitter.com',
#  'www.tr.news',
#  'www.bitchute.com',
#  'politichatter.com',
#  'youtu.be',
#  'youtu.be',
#  'youtu.be',
#  'twitter.com',
#  'twitter.com',
#  'twitter.com',
#  'par.pw',
#  'summit.news',
#  'summit.news',
#  'twitter.com',
#  'bigleaguepolitics.com',
#  'www.bbc.com',
#  'www.thegatewaypundit.com',
#  'twitter.com',
#  'twitter.com',
#  'twitter.com',
#  'twitter.com',
#  'petitions.whitehouse.gov',
#  'www.infowars.com',
#  'youtu.be',
#  'dailycaller.com',
#  'youtu.be',
#  'www.infowars.com',
#  'summit.news',
#  'ifw.io',
#  'infowars.com',
#  'infowars.com',
#  'infowars.com',
#  'twitter.com',
#  'twitter.com',
#  'lauraloomer.us',
#  'twitter.com',
#  'summit.news',
#  'summit.news',
#  'summit.news',
#  'summit.news',
#  'twitter.com',
#  'politichatter.com',
#  'www.tr.news',
#  'politichatter.com',
#  'politichatter.com',
#  'politichatter.com',
#  'lauraloomer.us',
#  'www.infowars.com',
#  'summit.news',
#  'summit.news',
#  'vdare.com',
#  't.co',
#  'www.infowars.com',
#  'twitter.com',
#  'davidharrisjr.com',
#  'lauraloomer.us',
#  'www.tr.news',
#  'twitter.com',
#  'ifw.io',
#  'infowars.com',
#  'infowars.com',
#  'infowars.com',
#  'infowarsstore.com',
#  'twitter.com',
#  ...]
